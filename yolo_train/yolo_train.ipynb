# %%
from ultralytics import YOLO
import cv2
from PIL import Image
import numpy as np

# %%
model = YOLO("yolov8n.pt")
model.to('cuda')

# %%
results = model.train(data="./config.yaml", epochs=10, imgsz=600)
# Out:
# New https://pypi.org/project/ultralytics/8.0.149 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.148  Python-3.11.4 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080, 12287MiB)
# ...

# %%
from pathlib import Path
image_path = Path("C:/Users/faust/code/dev-aircraft-ident/aircraft_training_data/004.png")

check = model.predict(image_path)
# Out:
# image 1/1 C:\Users\faust\code\dev-aircraft-ident\aircraft_training_data\004.png: 448x608 14 Aircrafts, 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 608)

# %%
image_data = check[0].plot()[:,:,::-1]
Image.fromarray(image_data)
# Out:
# <PIL.Image.Image image mode=RGB size=1614x1159>
