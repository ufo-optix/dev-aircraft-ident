# %%
from ultralytics import YOLO
import cv2
from PIL import Image
import numpy as np

# %%
model = YOLO("./models/8.8.23/aug_08_2023.pt")

# %%
from pathlib import Path
image_path = Path("./data/train/images/omdb_006_png.rf.9c70ed25c3f84cee64137de0b3799d3c.jpg")
check = model.predict(image_path, conf=0.5)

# %%
image_data = check[0].plot()[:,:,::-1]
Image.fromarray(image_data)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
